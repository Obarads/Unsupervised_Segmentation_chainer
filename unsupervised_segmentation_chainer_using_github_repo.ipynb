# %% [markdown]
# # unsupervised_segmentation_chainer
# ## About
# This repository is a chainer implementation of the method proposed by Kanezaki[1].
#
# ## How to use
# Please see below.
#
# ## Reference
# 1. [Asako Kanezaki. Unsupervised Image Segmentation by Backpropagation. IEEE International Conference on Acoustics, Speech and Signal Processing (ICASSP), 2018.](https://kanezaki.github.io/pytorch-unsupervised-segmentation/ICASSP2018_kanezaki.pdf)

# %% [markdown]
# ### 1. install repository

# %%
# !git clone https://github.com/Obarads/unsupervised_segmentation_chainer.git
# Out:
# Cloning into 'unsupervised_segmentation_chainer'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 71 (delta 31), reused 38 (delta 2), pack-reused 0
# Unpacking objects: 100% (71/71), done.

# %% [markdown]
# ### 2. Run

# %%
from unsupervised_segmentation_chainer import train

train.main(args=["--input","unsupervised_segmentation_chainer/images/108004.jpg","-g","0","-uc","true"])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !cd unsupervised_segmentation_chainer/ && git pull
# Out:
# Already up to date.
